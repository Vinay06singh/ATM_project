# %% [markdown]
# **Mini Project on using Python**

# %% [markdown]
# This Project is the model of Automated Teller Machine Using object oriented Programming Using Python.

# %% [markdown]
# **Features**

# %% [markdown]
# 1.Check saving balance
#
# 2.Deposit balance
#
# 3.Withdraw balance
#
# 4.Transfer fund
#
# 5.Exit

# %% [markdown]
# **Requirments**

# %% [markdown]
# *Python and  basic concept of OOPS
#
# *Python IDE

# %% [markdown]
# **CODE**

# %%
import sys

# %%
pin=1234
input_pin=int(input("Enter your 4 digit pin:"))
input_pins=int(input("Enter your 4 digit pin again:"))
if input_pin and input_pins==pin:
    class Atm:
        def __init__(self):
            self.saving_balance=0.00
            self.checking_balance=100000
            self.menu()
        def menu(self):
            print("""
            Please enter your choice!
                1.Check saving balance
                2.Deposit balance
                3.Withdraw balance
                4.Transfer fund
                5.Exit
            """)
            input_options=int(input("Enter your option:"))
            if input_options==1:
                self.check_balance()
            elif input_options==2:
                self.deposit_balance()
            elif input_options==3:
                self.withdraw_balance()
            elif input_options==4:
                self.transfer_fund()
            elif input_options==5:
                print("Thank You!")
                sys.exit()
        def check_balance(self):
            print(f"Your balance is {self.saving_balance}")
            self.menu()
        def deposit_balance(self):
            input_deposit=float(input("Enter the amount:"))
            self.saving_balance=self.saving_balance +input_deposit
            print(f"Your updated saving_balance is {self.saving_balance}")
            self.menu()
        def withdraw_balance(self):
            input_withdraw=float(input("Enter the amount:"))
            if input_withdraw<=self.saving_balance:
                self.saving_balance=self.saving_balance-input_withdraw
                print(f"Your updated saving_balance is {self.saving_balance}")
            else:
                print("Insufficient balance!")
            self.menu()
        def transfer_fund(self):
            input_transfer=float(input("Enter the amount to transfer: "))
            if input_transfer<=self.checking_balance:
                self.saving_balance=self.saving_balance+input_transfer
                self.checking_balance=self.checking_balance-input_transfer
                print(f"Your updated saving_balance is {self.saving_balance}")
                print(f"Your updated checking_balance is {self.checking_balance}")
            else:
                print("Insufficient balance")
            self.menu()
    sbi=Atm() 
else:
    print("Incorrect pin")
# Out:
# Enter your 4 digit pin:1234
# Enter your 4 digit pin again:1234
#
#             Please enter your choice!
#                 1.Check saving balance
#                 2.Deposit balance
#                 3.Withdraw balance
#                 4.Transfer fund
#                 5.Exit
#
# Enter your option:1
# Your balance is 0.0
#
#             Please enter your choice!
#                 1.Check saving balance
#                 2.Deposit balance
#                 3.Withdraw balance
#                 4.Transfer fund
#                 5.Exit
#
# Enter your option:2
# Enter the amount:5000
# Your updated saving_balance is 5000.0
#
#             Please enter your choice!
#                 1.Check saving balance
#                 2.Deposit balance
#                 3.Withdraw balance
#                 4.Transfer fund
#                 5.Exit
#
# Enter your option:3
# Enter the amount:2000
# Your updated saving_balance is 3000.0
#
#             Please enter your choice!
#                 1.Check saving balance
#                 2.Deposit balance
#                 3.Withdraw balance
#                 4.Transfer fund
#                 5.Exit
#
# Enter your option:4
# Enter the amount to transfer: 10000
# Your updated saving_balance is 13000.0
# Your updated checking_balance is 90000.0
#
#             Please enter your choice!
#                 1.Check saving balance
#                 2.Deposit balance
#                 3.Withdraw balance
#                 4.Transfer fund
#                 5.Exit
#
# Enter your option:5
# Thank You!
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3334: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
